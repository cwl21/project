# %%
import matplotlib.pyplot as plt

import csv



#path = '/media/chris/Backup Plus/csvs/' #  path for primary storage
path ='/home/chris/Documents/' #path for testing smaller csvs ~4MM lines

# %%
x = []
y = []

with open(path+'xaa.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(row[1])
        #print(x)
        y.append(row[2])
        #print(y)
print(x)
print(y)
plt.plot(x,y, label='Loaded from file!')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.title('Soundfile')
plt.legend()
plt.show()
# Out:
# ['12.141982024070565', '9.592600235081695', '9.979572275331448', '9.791276893003017', '9.512778941357421', '9.193984499984435', '7.573570638807642', '9.466380900757203', '8.206134457515423', '9.246946553106465', '8.817826033075828', '8.861311882453055', '9.349029853565417', '9.606566005437962', '8.743418671590353', '8.679121939625082', '9.940397230404091', '9.803387955949072', '9.31800007252659', '9.632991115039925', '8.792339946028154', '8.628495791473473', '10.038229820949715', '8.665921000505396', '8.971189877419302', '9.442836131143798', '9.42965756606478', '9.33514816448723', '9.443942692151174', '8.636919256315203', '9.163778654245005', '9.382762246050255', '8.695543008506833', '9.730885604824923', '9.481636410599396', '8.265678363880372', '9.833192173967264', '9.51839898557653', '9.792896764480746', '8.847317564017645', '9.77827944740469', '10.431574634238446', '10.578096717984982', '10.04776271502612', '9.653172463077807', '10.830380450291281', '9.148768261096052', '10.871540
# ...

# %%
import pandas as pd
data = pd.read_csv(path+'xaa.csv')

ts = pd.Series(data['12.141982024070565'], data['0.0'])
ts.plot()

# %%
data
# Out:
#            0  12.141982024070565       0.0
# 0          1            9.592600  0.000013
# 1          2            9.979572  0.000025
# 2          3            9.791277  0.000038
# 3          4            9.512779  0.000051
# 4          5            9.193984  0.000063
# ...      ...                 ...       ...
# 45599  45600            9.667935  0.421767
# 45600  45601            9.814682  0.421755
# 45601  45602            9.568982  0.421742
# 45602  45603            9.398867  0.421729
# 45603  45604            7.811130  0.400000
#
# [45604 rows x 3 columns]
